# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilan-Kaibili/regression/blob/master/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cdd3ba84-a7b7-4e1e-81ef-90cd5df9a95b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdd3ba84-a7b7-4e1e-81ef-90cd5df9a95b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as numpyInstace
import pandas as pandasInstance
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weatherData=pandasInstance.read_csv('weather.csv')
weatherData.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weatherData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
weatherData.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
sns.scatterplot(x='MinTemp',y='MaxTemp',data=weatherData)
# Out:
# <Axes: xlabel='MinTemp', ylabel='MaxTemp'>

# %%
sns.jointplot(x='MinTemp',y='MaxTemp',data=weatherData,kind='hex')

# %%
sns.lmplot(x='MinTemp',y='MaxTemp',data=weatherData,hue='RainTomorrow')

# %%
plt.figure(figsize=(10,10))
plt.tight_layout()
sns.distplot(weatherData['MaxTemp'])
# Out:
# /tmp/ipython-input-2714772212.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(weatherData['MaxTemp'])
# <Axes: xlabel='MaxTemp', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
plt.tight_layout()
sns.heatmap(weatherData.select_dtypes(include=['number']).corr(),annot=True)
# Out:
# <Axes: >

# %%
X_Prediction = weatherData[['Humidity3pm']]
print(X_Prediction)
# Out:
#      Humidity3pm
# 0             29
# 1             36
# 2             69
# 3             56
# 4             49
# ..           ...
# 361           15
# 362           22
# 363           47
# 364           39
# 365           13
#
# [366 rows x 1 columns]

# %%
y_test = weatherData['MaxTemp']
print(y_test)
# Out:
# 0      24.3
# 1      26.9
# 2      23.4
# 3      15.5
# 4      16.1
#        ...
# 361    30.7
# 362    28.4
# 363    19.9
# 364    26.9
# 365    30.2
# Name: MaxTemp, Length: 366, dtype: float64

# %%
coefficientInformation
# Out:
# array([-0.2117526])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_Prediction, y_test)
temperaturePredictions = model.predict(X_Prediction)

# %%
temperaturePredictions
# Out:
# array([23.83648839, 22.35422021, 15.36638452, 18.11916827, 19.60143645,
#        17.90741568, 20.02494165, 17.90741568, 19.81318905, 23.2012306 ,
#        22.7777254 , 22.56597281, 23.83648839, 25.74226176, 26.58927214,
#        25.31875656, 25.10700397, 24.47174618, 24.68349877, 24.25999358,
#        24.47174618, 14.73112673, 13.24885855, 17.90741568, 23.41298319,
#        19.81318905, 18.33092087, 23.41298319, 13.03710595, 19.60143645,
#        10.91957998, 20.23669424, 17.27215789, 21.50720982, 16.6369001 ,
#        18.54267347, 14.30762153, 21.08370463, 24.89525137, 22.14246761,
#        16.6369001 , 19.17793126, 19.60143645, 22.14246761, 22.35422021,
#        11.76659037, 21.50720982, 20.87195203, 18.54267347, 14.30762153,
#        19.81318905, 16.84865269, 19.60143645, 20.87195203, 18.96617866,
#        22.56597281, 16.4251475 , 20.66019944, 23.62473579, 26.16576695,
#        25.74226176, 25.74226176, 27.01277734, 18.33092087, 20.44844684,
# ...

# %%
matplotlibInstace.scatter(y_test,temperaturePredictions)

# %%
sns.distplot(y_test-temperaturePredictions)
# Out:
# /tmp/ipython-input-1446496936.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-temperaturePredictions)
# <Axes: xlabel='MaxTemp', ylabel='Density'>

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,temperaturePredictions)
# Out:
# 4.795208708286585

# %%
metrics.mean_squared_error(y_test,temperaturePredictions)
# Out:
# 31.943205641570433

# %%
numpyInstace.sqrt(metrics.mean_squared_error(y_test,temperaturePredictions))
# Out:
# np.float64(5.6518320606304675)

# %%
coefficientInformation
# Out:
# array([-0.2117526])
